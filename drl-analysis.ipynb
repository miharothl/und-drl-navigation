# %%
# %matplotlib inline

# %%
from drl import logging
from drl.experiment.analyser import Analyzer
from drl.experiment.config import Config
from drl.experiment.experiment import Experiment
from drl.experiment.explorer import Explorer
from drl.logging import init_logging, set_logging_level, transform_verbose_count_to_logging_level
import logging
import logging.config

# %%
init_logging(logging.ERROR)

# %%
config = Config()
environment = Experiment(config)
analyzer = Analyzer(config, environment.get_session_id())

# %%
experiments = [
    '_experiments/train/lunarlander-e1-20200728T1504',
    '_experiments/train/lunarlander-e2-20200728T1504',
    '_experiments/train/lunarlander-e3-20200728T1504',
    '_experiments/train/lunarlander-e4-20200728T1504',
    '_experiments/train/lunarlander-e5-20200728T1504',
    '_experiments/train/lunarlander-e6-20200728T1504',
]

# %%
experiments = [
    '_experiments/train/lunarlander-e6-20200728T1504',
    '_experiments/train/lunarlander-e7-20200728T1715',
    '_experiments/train/lunarlander-e8-20200728T1715',
    '_experiments/train/lunarlander-e61-20200728T1715',
    '_experiments/train/lunarlander-e62-20200728T1715',
    '_experiments/train/lunarlander-e63-20200728T1715',
    '_experiments/train/lunarlander-e64-20200728T1715',
]

# %%
experiments = [
    '_experiments/train/lunarlander-e6-20200728T1504',
    '_experiments/train/lunarlander-e601-20200728T1935',
    '_experiments/train/lunarlander-e602-20200728T1935',
    '_experiments/train/lunarlander-e603-20200728T1935',
    '_experiments/train/lunarlander-e604-20200728T1935',
    '_experiments/train/lunarlander-e6001-20200728T1935',
    '_experiments/train/lunarlander-e6002-20200728T1935',
    '_experiments/train/lunarlander-e6003-20200728T1935',
    '_experiments/train/lunarlander-e6004-20200728T1935',
]

# %%
experiments = [
    '_experiments/train/lunarlander-e6-20200728T1504',
    '_experiments/train/lunarlander-nn09-20200729T0828',
    '_experiments/train/lunarlander-nn10-20200729T0828',
    '_experiments/train/lunarlander-nn11-20200729T0828',
    '_experiments/train/lunarlander-nn12-20200729T0828',
    '_experiments/train/lunarlander-nn06-eps05-20200729T0828',
    '_experiments/train/lunarlander-nn06-eps06-20200729T0828',
    '_experiments/train/lunarlander-nn06-eps07-20200729T0828',
    '_experiments/train/lunarlander-nn06-eps08-20200729T0828',
]

# %%
experiments = [
#     '_experiments/train/breakout-nn01-20200729T1037',
#     '_experiments/train/breakout-nn02-20200729T1037',
#     '_experiments/train/breakout-nn03-20200729T1037',
#     '_experiments/train/breakout-nn04-20200729T1037',
    '_experiments/train/breakout-nn05-20200729T1037',
#     '_experiments/train/breakout-nn06-20200729T1037',
#     '_experiments/train/breakout-nn07-20200729T1037',
    '_experiments/train/breakout-nn08-20200729T1219',
#     '_experiments/train/breakout-nn09-20200729T1219',
#     '_experiments/train/breakout-nn10-20200729T1219',
#     '_experiments/train/breakout-nn11-20200729T1219',
    '_experiments/train/breakout-nn12-20200729T1219',
]

# %%
experiments = [
    '_experiments/train/breakout-nn01-20200729T1037',
#     '_experiments/train/breakout-nn02-20200729T1037',
#     '_experiments/train/breakout-nn03-20200729T1037',
#     '_experiments/train/breakout-nn04-20200729T1037',
#     '_experiments/train/breakout-nn05-20200729T1037',
#     '_experiments/train/breakout-nn06-20200729T1037',
    '_experiments/train/breakout-nn01-20200729T2133',
    '_experiments/train/breakout-nn02-20200729T2133',
    '_experiments/train/breakout-nn03-20200729T2133',
    '_experiments/train/breakout-nn04-20200729T2133',
    '_experiments/train/breakout-nn05-20200729T2133',
    '_experiments/train/breakout-nn06-20200729T2133',    
]

# %%
experiments = [
#     '_experiments/train/breakout-nn01-20200729T1037',
#     '_experiments/train/breakout-nn02-20200729T1037',
#     '_experiments/train/breakout-nn03-20200729T1037',
#     '_experiments/train/breakout-nn04-20200729T1037',
#     '_experiments/train/breakout-nn05-20200729T1037',
#     '_experiments/train/breakout-nn06-20200729T1037',
   
    '_experiments/train/breakout-nn02-20200729T2150',
    '_experiments/train/breakout-nn03-20200729T2150',
    '_experiments/train/breakout-nn04-20200729T2150',
    '_experiments/train/breakout-nn05-20200729T2150',
    '_experiments/train/breakout-nn06-20200729T2150',    
]

# %%
experiments = [
    '_experiments/train/breakout-nn07-20200729T1219',
    '_experiments/train/breakout-nn08-20200729T1219',
    '_experiments/train/breakout-nn09-20200729T1219',
    '_experiments/train/breakout-nn10-20200729T1219',
    '_experiments/train/breakout-nn11-20200729T1219',
    '_experiments/train/breakout-nn12-20200729T1219',

]

# %%
experiments = [
    '_experiments/train/breakout-nn05-20200729T1037',
    '_experiments/train/breakout-nn05-eps01-20200729T1401',
    '_experiments/train/breakout-nn05-eps02-20200729T1401',
    '_experiments/train/breakout-nn05-eps03-20200729T1401',
    '_experiments/train/breakout-nn12-eps01-20200729T1401',
    '_experiments/train/breakout-nn12-eps02-20200729T1401',
    '_experiments/train/breakout-nn12-eps03-20200729T1401',
    '_experiments/train/breakout-nn13-20200729T1401',

]

# %%
analyzer.compare_train_epoch_cols(experiments, 'epsilon', True)

# %%
analyzer.compare_train_epoch_cols(experiments, 'avg_score', True)

# %%
analyzer.compare_train_epoch_cols(experiments, 'avg_val_score', True)

# %%
analyzer.compare_train_epoch_cols(experiments, 'avg_loss', True)

# %%
analyzer.compare_train_config(experiments)
# Out:
# _experiments/train/breakout-nn05-20200729T1037
# {
#     "configuration": {
#         "agent": {
#             "action_size": 3,
#             "discrete": true,
#             "num_frames": 4,
#             "start_game_action": 0,
#             "start_game_action_required": true,
#             "state_offset": 1,
#             "state_rgb": false,
#             "state_size": 128
#         },
#         "env": {
#             "is_atari": true,
#             "terminate_reward": 0
#         },
#         "id": "Breakout-ram-v4",
#         "train": {
#             "epsilon": 0.995,
#             "eval_frequency": 20000,
#             "eval_steps": 3000,
#             "gamma": 0.99,
#             "human_flag": false,
#             "learning_rate": 0.0001,
#             "max_episode_steps": 2000,
#             "max_steps": 1000000,
#             "neural_network": [
#                 128,
#                 128,
#                 64
#             ],
#             "tau": 0.001
#         }
# ...
