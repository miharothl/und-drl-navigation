# %%
# %matplotlib inline

# %%
from drl import logging
from drl.experiment.analyser import Analyzer
from drl.experiment.config import Config
from drl.experiment.experiment import Experiment
from drl.experiment.explorer import Explorer
from drl.logging import init_logging, set_logging_level, transform_verbose_count_to_logging_level
import logging
import logging.config

# %%
init_logging(logging.ERROR)

# %%
config = Config()
environment = Experiment(config)
analyzer = Analyzer(config, environment.get_session_id())

# %%
experiments = [
#     '_experiments/train/banana-20200801T1244',
#     '_experiments/train/banana-20200802T2008',
#     '_experiments/train/banana-20200804T0640', # double
#     '_experiments/train/banana-20200804T0810', # dqn
#     '_experiments/train/banana-20200804T0902', # dueling
    '_experiments/train/banana-20200807T1756', # dueling eps=0.995, nn 64,64
#     '_experiments/train/banana-20200808T0722', # double eps=0.997, nn 64,64
#     '_experiments/train/banana-20200808T1137', # double eps=0.996, nn 64,64
    '_experiments/train/banana-20200808T1313', # double eps=0.995, nn 64,64
#     '_experiments/train/banana-20200808T1628', # double eps=0.995, nn 128:128
#     '_experiments/train/banana-20200809T0757', # dueling eps=0.995, nn 128:128
#     '_experiments/train/banana-20200809T0900', # dueling eps=0.995, nn 64:64, 4 frames
    '_experiments/train/banana-20200810T0725', # double eps=0.995, nn 64,64, 4 frames
    '_experiments/train/banana-20200810T1003', # double eps=0.995, nn 128,128, 4 frames
    '_experiments/train/banana-20200810T1130', # dueling eps=0.995, nn 128,128, 4 frames
    '_experiments/train/banana-20200810T1312', # dueling eps=0.995, nn 64,64, 4 frames
]

# %%
analyzer.compare_train_epoch_cols(experiments, 'epsilon', False)
# Out:
# '_experiments/analysis/lunarlander-20200807T1732/epsilon.png'

# %%
analyzer.compare_train_epoch_cols(experiments, 'avg_score', False)
# Out:
# '_experiments/analysis/lunarlander-20200807T1732/avg_score.png'

# %%
analyzer.compare_train_epoch_cols(experiments, 'avg_val_score', True)
# Out:
# /Users/rothlmi/scm/r/hub/lab-drlnd-navigation/drl/experiment/analyser.py:98: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
analyzer.compare_train_epoch_cols(experiments, 'beta', False)
# Out:
# '_experiments/analysis/lunarlander-20200807T1732/beta.png'

# %%
analyzer.compare_train_epoch_cols(experiments, 'avg_loss', True)
# Out:
# /Users/rothlmi/scm/r/hub/lab-drlnd-navigation/drl/experiment/analyser.py:98: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
analyzer.compare_train_config(experiments)
# Out:
# _experiments/train/banana-20200807T1756
# {
#     "configuration": {
#         "agent": {
#             "action_size": 4,
#             "discrete": true,
#             "num_frames": 1,
#             "start_game_action": 0,
#             "start_game_action_required": false,
#             "state_offset": 0,
#             "state_rgb": false,
#             "state_size": 37
#         },
#         "env": {
#             "is_atari": false,
#             "terminate_reward": 0,
#             "type": "unity"
#         },
#         "id": "env/unity/mac/banana",
#         "neural_network": {
#             "double": false,
#             "dueling": true,
#             "hidden_layers": [
#                 64,
#                 64
#             ]
#         },
#         "replay_memory": {
#             "buffer_size": 100000,
#             "prioritized_replay": true,
#             "prioritized_replay_alpha": 0.6,
#             "prioritized_replay_beta0": 0.4,
#             "prioritized_replay_eps": 1e-06
#         },
#         "train": {
#             "batch_size": 64,
#             "epsilon": 0.995,
#             "eval_frequency": 10200,
#             "eval_steps": 2100,
#             "gamma": 0.99,
#             "human_flag": false,
#             "learning_rate": 0.0001,
#             "max_episode_steps": 1000,
#             "max_steps": 600000,
#             "tau": 0.001,
#             "update_every": 4
#         }
#     },
#     "model": null,
#     "session_id": "banana-20200807T1756"
# }
# _experiments/train/banana-20200808T1313
# {
#     "configuration": {
#         "agent": {
#             "action_size": 4,
#             "discrete": true,
#             "num_frames": 1,
#             "start_game_action": 0,
#             "start_game_action_required": false,
#             "state_offset": 0,
#             "state_rgb": false,
#             "state_size": 37
#         },
#         "env": {
#             "is_atari": false,
#             "terminate_reward": 0,
#             "type": "unity"
#         },
#         "id": "env/unity/mac/banana",
#         "neural_network": {
#             "double": true,
#             "dueling": false,
#             "hidden_layers": [
#                 64,
#                 64
#             ]
#         },
#         "replay_memory": {
#             "buffer_size": 100000,
#             "prioritized_replay": true,
#             "prioritized_replay_alpha": 0.6,
#             "prioritized_replay_beta0": 0.4,
#             "prioritized_replay_eps": 1e-06
#         },
#         "train": {
#             "batch_size": 64,
#             "epsilon": 0.995,
#             "eval_frequency": 10200,
#             "eval_steps": 2100,
#             "gamma": 0.99,
#             "human_flag": false,
#             "learning_rate": 0.0001,
#             "max_episode_steps": 1000,
#             "max_steps": 600000,
#             "tau": 0.001,
#             "update_every": 4
#         }
#     },
#     "model": null,
#     "session_id": "banana-20200808T1313"
# }
# _experiments/train/banana-20200810T0725
# {
#     "configuration": {
#         "agent": {
#             "action_size": 4,
#             "discrete": true,
#             "num_frames": 4,
#             "start_game_action": 0,
#             "start_game_action_required": false,
#             "state_offset": 0,
#             "state_rgb": false,
#             "state_size": 37
#         },
#         "env": {
#             "is_atari": false,
#             "terminate_reward": 0,
#             "type": "unity"
#         },
#         "id": "env/unity/mac/banana",
#         "neural_network": {
#             "double": true,
#             "dueling": false,
#             "hidden_layers": [
#                 64,
#                 64
#             ]
#         },
#         "replay_memory": {
#             "buffer_size": 100000,
#             "prioritized_replay": true,
#             "prioritized_replay_alpha": 0.6,
#             "prioritized_replay_beta0": 0.4,
#             "prioritized_replay_eps": 1e-06
#         },
#         "train": {
#             "batch_size": 64,
#             "epsilon": 0.995,
#             "eval_frequency": 10200,
#             "eval_steps": 2100,
#             "gamma": 0.99,
#             "human_flag": false,
#             "learning_rate": 0.0001,
#             "max_episode_steps": 1000,
#             "max_steps": 600000,
#             "tau": 0.001,
#             "update_every": 4
#         }
#     },
#     "model": null,
#     "session_id": "banana-20200810T0725"
# }
# _experiments/train/banana-20200810T1003
# {
#     "configuration": {
#         "agent": {
#             "action_size": 4,
#             "discrete": true,
#             "num_frames": 4,
#             "start_game_action": 0,
#             "start_game_action_required": false,
#             "state_offset": 0,
#             "state_rgb": false,
#             "state_size": 37
#         },
#         "env": {
#             "is_atari": false,
#             "terminate_reward": 0,
#             "type": "unity"
#         },
#         "id": "env/unity/mac/banana",
#         "neural_network": {
#             "double": true,
#             "dueling": false,
#             "hidden_layers": [
#                 128,
#                 128
#             ]
#         },
#         "replay_memory": {
#             "buffer_size": 100000,
#             "prioritized_replay": true,
#             "prioritized_replay_alpha": 0.6,
#             "prioritized_replay_beta0": 0.4,
#             "prioritized_replay_eps": 1e-06
#         },
#         "train": {
#             "batch_size": 64,
#             "epsilon": 0.995,
#             "eval_frequency": 10200,
#             "eval_steps": 2100,
#             "gamma": 0.99,
#             "human_flag": false,
#             "learning_rate": 0.0001,
#             "max_episode_steps": 1000,
#             "max_steps": 600000,
#             "tau": 0.001,
#             "update_every": 4
#         }
#     },
#     "model": null,
#     "session_id": "banana-20200810T1003"
# }
# _experiments/train/banana-20200810T1130
# {
#     "configuration": {
#         "agent": {
#             "action_size": 4,
#             "discrete": true,
#             "num_frames": 4,
#             "start_game_action": 0,
#             "start_game_action_required": false,
#             "state_offset": 0,
#             "state_rgb": false,
#             "state_size": 37
#         },
#         "env": {
#             "is_atari": false,
#             "terminate_reward": 0,
#             "type": "unity"
#         },
#         "id": "env/unity/mac/banana",
#         "neural_network": {
#             "double": false,
#             "dueling": true,
#             "hidden_layers": [
#                 128,
#                 128
#             ]
#         },
#         "replay_memory": {
#             "buffer_size": 100000,
#             "prioritized_replay": true,
#             "prioritized_replay_alpha": 0.6,
#             "prioritized_replay_beta0": 0.4,
#             "prioritized_replay_eps": 1e-06
#         },
#         "train": {
#             "batch_size": 64,
#             "epsilon": 0.995,
#             "eval_frequency": 10200,
#             "eval_steps": 2100,
#             "gamma": 0.99,
#             "human_flag": false,
#             "learning_rate": 0.0001,
#             "max_episode_steps": 1000,
#             "max_steps": 600000,
#             "tau": 0.001,
#             "update_every": 4
#         }
#     },
#     "model": null,
#     "session_id": "banana-20200810T1130"
# }
# _experiments/train/banana-20200810T1312
# {
#     "configuration": {
#         "agent": {
#             "action_size": 4,
#             "discrete": true,
#             "num_frames": 4,
#             "start_game_action": 0,
#             "start_game_action_required": false,
#             "state_offset": 0,
#             "state_rgb": false,
#             "state_size": 37
#         },
#         "env": {
#             "is_atari": false,
#             "terminate_reward": 0,
#             "type": "unity"
#         },
#         "id": "env/unity/mac/banana",
#         "neural_network": {
#             "double": false,
#             "dueling": true,
#             "hidden_layers": [
#                 64,
#                 64
#             ]
#         },
#         "replay_memory": {
#             "buffer_size": 100000,
#             "prioritized_replay": true,
#             "prioritized_replay_alpha": 0.6,
#             "prioritized_replay_beta0": 0.4,
#             "prioritized_replay_eps": 1e-06
#         },
#         "train": {
#             "batch_size": 64,
#             "epsilon": 0.995,
#             "eval_frequency": 10200,
#             "eval_steps": 2100,
#             "gamma": 0.99,
#             "human_flag": false,
#             "learning_rate": 0.0001,
#             "max_episode_steps": 1000,
#             "max_steps": 600000,
#             "tau": 0.001,
#             "update_every": 4
#         }
#     },
#     "model": null,
#     "session_id": "banana-20200810T1312"
# }
